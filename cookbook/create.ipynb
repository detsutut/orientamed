# %%
from retriever import Retriever
from app_utils import get_mfa_response
import boto3
import pandas as pd
from langchain_core.documents import Document

# %%
mfa_response = get_mfa_response("697648")
if mfa_response is not None:
    session = boto3.Session(aws_access_key_id=mfa_response['Credentials']['AccessKeyId'],
                            aws_secret_access_key=mfa_response['Credentials']['SecretAccessKey'],
                            aws_session_token=mfa_response['Credentials']['SessionToken'])
client = session.client("bedrock-runtime", region_name='eu-west-1')

# %%
retriever = Retriever('cohere.embed-multilingual-v3', client=client)

# %%
df = pd.read_csv("/home/tommaso/Downloads/export (3).csv", header=0)

# %%
documents = []
for index,id,title,text in df.itertuples():
    doc = Document(id=id, page_content=text, metadata={"title": title, "doc_id":id, "source": id.split(".txt")[0]})
    documents.append(doc)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,  # Make sure it's less than 2048
    chunk_overlap=100  # Optional: small overlap to preserve context
)

chunks = text_splitter.split_documents(documents)

# %%
_ = retriever.vector_store.add_documents(documents=chunks)

# %%
retriever.save_vector_store("./reuma_250507.db")

# %%
documents
# Out:
# [Document(id='2023 Malattia da deposito calcio pirofosfato.txt--paragraph1.', metadata={'title': ' Criteri classificativi della malattia da deposito di calcio pirofosfato', 'source': '2023 Malattia da deposito calcio pirofosfato'}, page_content='1. Criteri classificativi della malattia da deposito di calcio pirofosfato\nTra i pazienti con dolore, gonfiore o dolorabilità alle articolazioni (criterio di ingresso) i cui sintomi non sono completamente spiegati da una malattia alternativa (criterio di esclusione), la presenza della sindrome del dente incoronato o di cristalli di calcio pirofosfato nel liquido sinoviale sono sufficienti per classificare un paziente come affetto da malattia da deposito di calcio pirofosfato.\n '),
#  Document(id='2023 Malattia da deposito calcio pirofosfato.txt--paragraph1.1.', metadata={'title': ' Sviluppo dei criteri classificativi fase 1 e 2', 'source': '2023 Malattia da deposito calcio pirofosfato'}, page_content="1.1. Sviluppo dei criteri classificativi fase 1 e 2\nNella fase 1, è stato elaborato un elenco completo dei potenziali criteri di classificazione sulla base di una revisione della letteratura e dell'input da parte del Comitato Misto di Esperti (CEC) e due pazienti partner di ricerca. \nNella fase 2 è stato ridotto e raffinato elenco delle potenziali voci considerate più specifiche per la malattia da deposito di calcio pirofosfato. Questi potenziali elementi sono stati inclusi nella scheda di raccolta dati (CRF) che è stata utilizzata per raccogliere i profili dei pazienti nelle coorti di derivazione e convalida.\n"),
#  Document(id='2023 Malattia da deposito calcio pirofosfato.txt--paragraph1.2.', metadata={'title': ' Sistema dei criteri di classificazione', 'source': '2023 Malattia da deposito calcio pirofosfato'}, page_content='1.2. Sistema dei criteri di classificazione\nIl CEC ha deciso di includere i criteri di ingresso (necessari da considerare per la classificazione della malattia da deposito di calcio pirofosfato) così come i criteri di esclusione (se presenti la classificazione come malattia da deposito di calcio pirofosfato non dovrebbe procedere) e ha creato la bozza iniziale del sistema dei criteri di classificazione. Il sistema è costituito da domini che comprendono voci simili.\n'),
#  Document(id='2023 Malattia da deposito calcio pirofosfato.txt--paragraph1.2.1.', metadata={'title': ' Fattori chiave del sistema di classificazione', 'source': '2023 Malattia da deposito calcio pirofosfato'}, page_content="1.2.1. Fattori chiave del sistema di classificazione\nIl CEC ha indentificato dei fattori chiave importanti per distinguere la malattia da deposito di calcio pirofosfato da imitazioni esaminando la classifica dei risultati e ORs. Questi fattori chiave sono: presenza di cristalli di calcio pirofosfato nel liquido sinoviale (o nel tessuto della biopsia), presenza della sindrome del dente coronato, comparsa dei sintomi dopo i 60 anni, artrite infiammatoria persistente, episodi tipici di artrite infiammatoria acuta definiti dall'insorgenza acuta o dal peggioramento acuto del dolore articolare con gonfiore e/o calore delle articolazioni che si risolve indipendentemente dal trattamento, localizzazione degli episodi tipici (ginocchio, polso, prima articolazione metatarsofalangea, altre articolazioni periferiche), condizioni metaboliche che predispongono alla CPP (emocromatosi ereditaria, iperparatiroidismo primario, ipomagnesemia, sindrome di Gitelman, ipofosfatasia, o storia familiare della malattia da deposito di calcio pirofosfato), osteoartrite radiografica di articolazioni specifiche della mano (articolazione scafo-trapezio-trapezoidale senza coinvolgimento della prima articolazione carpometacarpale, articolazione radio-carpale, seconda articolazione metacarpo-falangea, terza articolazione metacarpo-falangea), e evidenze di imaging della malattia da deposito di calcio pirofosfato (calcificazione lineare o puntiforme nella cartilagine ialina o fibrocartilagine) nelle articolazioni periferiche.\n"),
#  Document(id='2023 Malattia da deposito calcio pirofosfato.txt--paragraph1.3.', metadata={'title': ' Sequenza del sistema di classificazione', 'source': '2023 Malattia da deposito calcio pirofosfato'}, page_content="1.3. Sequenza del sistema di classificazione\nIl sistema di classificazione della malattia da deposito di calcio pirofosfato deve essere applicato con la seguente sequenza:\n(1) i criteri di ingresso devono essere soddisfatti;\n(2) i criteri di esclusione devono essere assenti\n(3) i criteri sufficienti devono essere valutati (presenza o assenza);\n(4) se i criteri sufficienti sono assenti, procedere con il punteggio dei domini.\nPer essere classificato come affetto da CPP, un individuo deve aver avuto almeno un episodio di dolore, gonfiore o dolorabilità articolare alle articolazioni periferiche o assiali (criterio di ingresso). Una CPP sintomatica è richiesta per la classificazione. \nI criteri di esclusione servono ad identificare gli individui in cui tutti i sintomi muscoloscheletrici potenzialmente attribuibili alla CPP sono più probabilmente spiegati da una condizione alternativa come artrite reumatoide, gotta, spondiloartrite periferica, o osteoartrite, ai quali non dovrebbero essere applicati ulteriormente i criteri di classificazione.\nDue criteri sufficienti sono stati concordati: sindrome del dente incoronato e l'analisi del liquido sinoviale che dimostra la presenza di cristalli di calcio pirofosfato in un'articolazione con gonfiore, dolorabilità o dolore.\nI criteri sufficienti sono soddisfatti anche se i cristalli di calcio pirofosfato sono rilevati dalla valutazione istopatologica del tessuto articolare.\n"),
#  Document(id='2023 Malattia da deposito calcio pirofosfato.txt--paragraph1.4.', metadata={'title': ' ACR/EULAR criteri di classificazione per la CPP', 'source': '2023 Malattia da deposito calcio pirofosfato'}, page_content="1.4. ACR/EULAR criteri di classificazione per la CPP\nIl sistema di classificazione della malattia da deposito di calcio pirofosfato dovrebbe essere applicato con il seguente ordine:\n(1) Criteri di ingresso: ha avuto almeno un episodio di dolore, gonfiore o dolorabilità articolare (episodio che si verifica in un'articolazione periferica o, nel caso della sindrome del dente incoronato, in una giunzione assiale come C1/C2).\n(2) Criteri assoluti di esclusione: tutti i sintomi sono più probabilmente spiegati da una condizione alternativa (come artrite reumatoide, gotta, spondiloartrite periferica, osteoartrite, ecc.).\n(3) Criteri sufficienti: presenza della sindrome del dente incoronato e l'analisi del liquido sinoviale che dimostra la presenza di cristalli di calcio pirofosfato in un'articolazione con gonfiore, dolorabilità o dolore. La sindrome del dente incoronato è definita come presenza di a) caratteristiche cliniche e b) caratteristiche di imaging. Le caratteristiche cliniche  comprendono l'insorgenza acuta o sub-acuta di dolore grave localizzato nella parte superiore del collo con marcatori di infiammazione elevati, rotazione limitata e spesso febbre. Condizioni imitative come polimialgia reumatica e meningite dovrebbero essere escluse. Le caratteristiche di imaging includono la CT convenzionale che mostra depositi calcifici, tipicamente lineari e meno densi dell'osso corticale, nel legamento trasverso retro-odontoide (legamento trasversale dell'atlante), spesso con un aspetto di 2 linee parallele nelle viste assiali. Calcificazioni nell'articolazione atlanto-assiale, nel legamento alare e/o nel pannus retro-odontoidale sono anch'esse caratteristiche. Le caratteristiche della tomografia computerizzata a doppia energia (DECT) includono un indice di doppia energia compreso tra 0,016 e 0,036. Devono essere presenti sia le caratteristiche cliniche che quelle di imaging. Criteri sufficienti sono soddisfatti anche se i cristalli di pirofosfato di calcio sono dimostrati con un'analisi istopatologica del tessuto articolare, a condizione che il paziente sia idoneo alla classificazione, cioè non soddisfi già i criteri di esclusione. Per esempio, la deposizione di cristalli di calcio pirofosfato nella cartilagine articolare in pazienti con osteoartrite allo stadio terminale (OA) non può essere utilizzata per classificare il paziente come affetto da malattia da deposito di calcio pirofosfato, quando tutti i sintomi sono meglio spiegati dalla presenza di OA (criteri di esclusione).\nUn individuo è classificato come affetto da malattia da deposito di calcio pirofosfato se i criteri di ingresso sono soddisfatti, i criteri di esclusione non sono soddisfatti e almeno un criterio sufficiente è soddisfatto. \n"),
#  Document(id='2023 Malattia da deposito calcio pirofosfato.txt--paragraph1.4.1.', metadata={'title': ' Punteggi per la classificazione', 'source': '2023 Malattia da deposito calcio pirofosfato'}, page_content="1.4.1. Punteggi per la classificazione\nGli elementi possono essere valutati se sono stati mai presenti durante la vita di un paziente. Se un paziente soddisfa > 1 elemento in un determinato dominio, verrà valutato solo l'elemento più alto ponderato. L'analisi imaging di almeno un articolazione sintomatica mediante CR, US, CT o DECT è necessaria.\n\n- Età della comparsa dei sintomi (dolore, gonfiore e/o dolorabilità):\n\t- ≤60 anni: 0 punti\n\t- >60 anni: 4 punti\n- Durata e sintomi dell'artrite infiammatoria:\n\t- Non persistente o tipica artrite infiammatoria: 0 punti\n\t- Persistente artrite infiammatoria: 9 punti\n\t- Un episodio acuto tipico dell'artrite: 12 punti\n\t- Più di un episodio acuto tipico dell'artrite: 16 punti\n- Siti di episodi tipici di artrite infiammatoria nelle articolazioni periferiche:\n\t- Prima articolazione metatarsofalangea: -6 punti\n\t- Nessun episodio tipico: 0 punti\n\t- Articolazioni diverse da polso, ginocchio o prima articolazione metatarsofalangea: 5 punti\n\t- Polso: 8 punti\n\t- Ginocchio: 9 punti\n- Malattie metaboliche collegate:\n\t- Nessuna: 0 punti\n\t- Presenza: 6 punti\n- Analisi dei cristalli nel liquido sinoviale di un'articolazione sintomatica:\n\t- Cristalli di calcio pirofosfato assenti in 2 occasioni: -7 punti\n\t- Cristalli di calcio pirofosfato assenti in 1 occasione: -1 punto\n\t- Non eseguita: 0 punti\n- Osteoartrite della mano/polso sull'imaging (definita come presente se il punteggio K/L è ≥2):\n\t- Nessuno dei risultati di seguito o nessuna immagine polso/mano eseguita: 0 punti\n\t- Osteoartrite bilaterale dell'articolazione radio carpale: 2 punti\n\t- ≥2 delle seguenti evidenze: osteoartrite dell'articolazione scafo-trapezio-trapezoidale senza osteoartrite della prima articolazione carpometacarpale; osteoartrite della seconda articolazione metacarpofalangea; osteoartrite della terza articolazione metacarpofalangea: 7 punti\n- Evidenza tramite imaging della malattia da deposito di calcio pirofosfato in articolazioni periferiche sintomatiche:\n\t- Nessuna su US, CT o DECT (e assente su CR o CR non eseguito): -4 punti\n\t- Nessuna su CR (e US, CT, DECT non eseguite): 0 punti\n\t- Presente su CR, US, CT o DECT: 16 punti\n- Numero di articolazioni periferiche con evidenza della malattia da deposito di calcio pirofosfato in qualsiasi modalità di imaging indipendentemente dai sintomi:\n\t- Nessuna: 0 punti\n\t- 1: 16 punti\n\t- 2-3: 23 punti\n\t- ≥4: 25 punti\n\nI criteri evidenziano l'importanza della prova mediante immagini di deposito di cristalli di calcio pirofosfato.\n"),
#  Document(id='Artrite_polimialgica_2012.txt--paragraph1.', metadata={'title': ' Criteri di classificazione provvisori per la polimialgia reumatica', 'source': 'Artrite_polimialgica_2012'}, page_content='1. Criteri di classificazione provvisori per la polimialgia reumatica\nL’obiettivo di questo studio è sviluppare criteri classificativi per la polimialgia reumatica. E’ stato formulato un algoritmo di assegnazione di punteggi ai criteri classificativi basato su rigidità mattutina maggiore di 45 minuti, dolore all’anca/ROM(range of motion)  limitato, assenza del fattore reumatoide (RF)  e/o anticorpi anti peptidi ciclici citrullinati (ACPA) e dolore alle articolazioni periferiche. In presenza di rigidità mattutina maggiore di 45 minuti, elevato livello di proteina C-reattiva e/o di velocità di eritrosedimentazione e dolore all’anca, pazienti con età uguale o superiore a 50 anni che presentano dolore alle spalle, non attribuibile a patologie alternative, possono essere classificati come affetti da polimialgia reumatica.\n\n'),
#  Document(id='Artrite_polimialgica_2012.txt--paragraph1.1.', metadata={'title': ' Decisioni consensuali sul disegno dello studio', 'source': 'Artrite_polimialgica_2012'}, page_content="1.1. Decisioni consensuali sul disegno dello studio\nI pazienti che presentano una sindrome polimialgica dovrebbero avere una valutazione basata su criteri di esclusione e inclusione. Per verificare la classificazione del paziente come affetto da polimialgia reumatica si può anche utilizzare la risposta alla terapia corticosteroidea (maggiore del 75% della risposta globale entro 1 settimana al prednisone/prednisolone 15-20 mg al giorno).\nLa nuova insorgenza di dolore alle spalle è stata considerata come il principale criterio di eleggibilità.\nI criteri sono età superiore ai 50 anni, durata dei sintomi di 2 o più settimane,dolori bilaterali alle spalle e/o al cinto pelvico,recente perdita di peso superiore a 2 kg,durata della rigidità mattutina superiore a 45 minuti, elevata velocità di eritrosedimentazione e risposta alla terapia corticosteroidea maggiore del 75% della risposta globale entro 1 settimana al prednisone/prednisolone 15-20 mg al giorno.\nL’esame obiettivo include la presenza o assenza di dolorabilità, dolore durante il movimento e limitazione di spalle e anche.Sono stati documentati gli aspetti della terapia corticosteroidea, tra cui la dose, la risposta terapeutica, la modifica della dose e l'interruzione della terapia.  \nSia soggetti affetti da polimialgia reumatica sia non affetti sono stati sottoposti a valutazione tramite ecografia delle spalle e delle anche alla valutazione basale e a 26 settimane. L’esame è stato condotto per accertare la presenza di caratteristiche precedentemente riportate  come associate alla polimialgia reumatica, ossia tenosivite del tendine del capo lungo del bicipite,borsite subacromiale e subdeltoidea, borsite trocanterica e versamento gleno-omerale e dell’anca.\n"),
#  Document(id='Artrite_polimialgica_2012.txt--paragraph1.2.', metadata={'title': ' Sviluppo di un algoritmo di assegnazione dei punteggi', 'source': 'Artrite_polimialgica_2012'}, page_content='1.2. Sviluppo di un algoritmo di assegnazione dei punteggi\nSono sufficienti quattro fattori per rappresentare tutti i criteri, che sono: dolore/dolorabilità alle anche, sinovite periferica o dolore alle articolazioni periferiche (quale criterio che riduce la probabilità), rigidità mattutina e dolorabilità delle spalle.\nL’algoritmo di assegnazione dei punteggi ai criteri di classificazione per polimialgia reumatica è il seguente:\n-Rigidità mattutina con durata maggiore di 45 minuti \n-Dolore all’anca e limitato range di movimento\n-Assenza di fattore reumatoide o anticorpi anti peptidi ciclici citrullinati\n-Assenza di coinvolgimento di altre sedi articolari \n-Almeno una spalla con borsite subdeltoidea e/o tenosivite del tendine del capo lungo del bicipite e/o sinovite gleno-omerale (nei recessi posteriore e/o ascellare) e almeno un’anca con sinovite e/o borsite trocanterica.\n-Entrambe le spalle con borsite subdeltoidea, tenosivite del capo lungo del bicipite o sinovite gleno-omerale.\n\nCriteri richiesti necessari per l’applicazione dei criteri classificativi:  età uguale o maggiore a 50 anni, dolore alle spalle ed elevazione del livello di proteina C-reattiva e/o della velocità di eritrosedimentazione (VES). \n'),
#  Document(id='Artrite_polimialgica_2012.txt--paragraph1.3.', metadata={'title': ' Discussione', 'source': 'Artrite_polimialgica_2012'}, page_content='1.3. Discussione\nLa popolazione target è di pazienti con un’età pari o superiore a 50 anni che presentano un dolore bilaterale alla spalla di recente insorgenza (<12 settimane) e una risposta anomala alla fase acuta.I criteri possono essere applicati solo a quei pazienti in cui i sintomi non sono meglio spiegati da una diagnosi alternativa. Le condizioni mimetiche includono le condizioni infiammatorie e non infiammatorie studiate come comparatori in questo rapporto.\nQuattro criteri clinici e di laboratorio, insieme ad altri criteri opzionali, possono essere applicati per identificare pazienti affetti da polimialgia reumatica adatti per terapia corticosteroidea a bassa dose. La scala di punteggio è 0-6 (senza ecografia muscoloscheletrica) e 0-8 (con ecografia muscoloscheletrica). In assenza di altre diagnosi concomitanti, un punteggio di 4 o maggiore (senza ecografia muscoloscheletrica) o di 5 o maggiore (con ecografia muscoloscheletrica) è indicativo di polimialgia reumatica. Pazienti con punteggi inferiori non possono essere considerati affetti. \nIn conclusione pazienti con età uguale o superiore ai 50 anni che presentano dolore alle spalle e livelli elevati di proteina C-reattiva e/o di velocità di eritrosedimentazione (VES) possono essere classificati come affetti da polimialgia reumatica in presenza di rigidità mattutina per più di 45 minuti e dolore alle anche in assenza di sinovite periferica e di test sierologico positivo al fattore reumatoide.'),
#  Document(id='Artrite_psoriasica_2006.txt--paragraph1.', metadata={'title': " Criteri di classificazione dell'artrite psoriasi", 'source': 'Artrite_psoriasica_2006'}, page_content="1. Criteri di classificazione dell'artrite psoriasi\nI criteri CASPAR ( Criteri di Classificazione per Artrite Psoriasica) comprendono la presenza di una malattia infiammatoria articolare accertata con almeno 3 punti assegnati dalle seguenti caratteristiche: psoriasi attuale (ha un punteggio assegnato di 2 punti, a tutte le altre caratteristiche è stato assegnato 1 punto), storia pregressa di psoriasi (a meno che non sia presente attualmente psoriasi), anamnesi familiare di psoriasi (a meno che non sia presente psoriasi attuale o storia di psoriasi pregressa), dattilite, osteoapposizione iuxta-articolare, fattore reumatoide negativo e distrofia ungueale.\n\n"),
#  Document(id='Artrite_psoriasica_2006.txt--paragraph1.1.', metadata={'title': ' Risultati', 'source': 'Artrite_psoriasica_2006'}, page_content="1.1. Risultati\nTutte le seguenti variabili sono indipendentemente associate all’artrite psoriasica: psoriasi attuale, anamnesi familiare di psoriasi, storia pregressa di psoriasi, risultato negativo al test del fattore reumatoide e osteoapposizione iuxta-articolare visto sulle radiografie.\nIn aggiunta a queste variabili identificate dalla regressione logistica come predittive dell’artrite psoriasica, l’analisi CART identifica: distrofia ungueale, storia pregressa di psoriasi( se non vi sono evidenze attuali di psoriasi), evidenza attuale di psoriasi, dattilite, storia pregressa di dattilite (se non vi è evidenza attuale di dattilite), formazione di tessuto osseo iuxta-articolare (tramite radiografia semplice di mani e piedi), storia familiare di psoriasi( se non vi sono evidenze attuali o pregresse di psoriasi) e un risultato negativo al test del fattore reumatoide.\nE’ stato assegnato un peso maggiore alla psoriasi attuale rispetto ad altre possibili caratteristiche di psoriasi.\n\nPer soddisfare i criteri CASPAR (Criteri di Classificazione per Artrite Psoriasica), un paziente deve avere una malattia infiammatoria articolare (articolazione, colonna vertebrale o entesi) con un punteggio maggiore o uguale a 3 punti derivanti dalle seguenti 5 categorie:\n-Evidenza attuale di psoriasi, anamnesi personale di psoriasi o anamnesi familiare di psoriasi. Psoriasi attuale è definita come malattia psoriasica della pelle o del cuoio capelluto presente oggi, secondo il giudizio di un reumatologo o di un dermatologo. Per anamnesi personale di psoriasi si intende un'anamnesi di psoriasi che può essere ottenuta da un medico di famiglia, da un dermatologo, da un reumatologo o altro operatore sanitario qualificato. Per anamnesi familiare di psoriasi si intende un'anamnesi di psoriasi in un parente di primo o secondo grado secondo quanto riferito dal paziente (che include quindi genitori, nonni, zii, fratelli, figli, nipoti)\n-Tipica distrofia ungueale psoriasica, che comprende onicolisi, pitting ungueale e ipercheratosi osservati in un esame obiettivo attuale.\n-Un risultato negativo del fattore reumatoide con qualsiasi metodo, eccetto quello al lattice, ma preferibilmente con un test di immunoassorbimetria o nefelometria, secondo l'intervallo di riferimento del laboratorio locale.\n-Dattilite in corso, definita come gonfiore di un intero dito, oppure storia pregressa di dattilite riportata da un reumatologo.\n-Evidenza radiografica di osteoapposizione iuxta-articolare, che appaia su radiografie della mano o del piede come un'ossificazione mal definita vicino ai margini dell'articolazione (escludendo formazioni osteofitiche).\nI criteri CASPAR hanno specificità pari al 98,7% e sensitività pari al 91,4%.\nAll’evidenza attuale di psoriasi è assegnato un punteggio di 2, a tutte le altre caratteristiche è assegnato un punteggio di 1.\n"),
#  Document(id='Artrite_psoriasica_2006.txt--paragraph1.2.', metadata={'title': ' Discussione', 'source': 'Artrite_psoriasica_2006'}, page_content='1.2. Discussione\nUn punto di forza di questi criteri è che permettono la diagnosi di artrite psoriasica nonostante la positività al fattore reumatoide o l’assenza di psoriasi, fintanto che altri segni tipici dell’artrite psoriasica sono presenti.\nLa maggiore limitazione di questo studio è che è stato condotto su soggetti con malattia infiammatoria articolare nota e dunque non è possibile applicare i risultati a soggetti con malattia recentemente insorta.'),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.', metadata={'title': " Criteri classificativi dell'artrite reumatoide 2010", 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content='1. Criteri classificativi dell\'artrite reumatoide 2010\nIl lavoro si è concentrato sull\'identificazione, tra i pazienti che presentano una sinovite, dei fattori che meglio discriminavano tra coloro che erano e quelli che non erano ad alto rischio di malattia persistente e/o erosiva - questo è il paradigma attuale che sta alla base del costrutto di malattia artrite reumatoide.\nLa classificazione come \\"artrite reumatoide definita\\" si basa sulla presenza accertata di sinovite/tumefazione articolare in almeno un\'articolazione, sull\'assenza di una diagnosi alternativa che spieghi meglio la sinovite  e sul raggiungimento di un punteggio totale pari o superiore a 6 (su un possibile 10) dai punteggi individuali in quattro domini: numero e sede delle articolazioni coinvolte (range 0-5), anomalie sierologiche (range 0-3), elevazione degli indici di fase acuta (range 0-1) e durata dei sintomi (due livelli; range 0-1). Questo nuovo sistema di classificazione ridefinisce l\'attuale paradigma dell\'artrite reumatoide, concentrandosi sulle caratteristiche nelle fasi più precoci della malattia che sono associate alla malattia persistente e/o erosiva, piuttosto che definirla dalle caratteristiche dello stadio avanzato.\n'),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.1.', metadata={'title': ' Eleggibilità all’applicazione dei nuovi criteri', 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content="1.1. Eleggibilità all’applicazione dei nuovi criteri\nI criteri classificativi possono essere applicati a qualsiasi paziente o individuo, purché siano soddisfatti due requisiti obbligatori: in primo luogo, deve esserci evidenza di una sinovite clinica attualmente attiva (cioè tumefazione) in almeno un'articolazione, determinata da un valutatore esperto. Tutte le articolazioni di una conta articolare completa possono essere valutate a questo scopo, ad eccezione delle articolazioni interfalangee distali (IFD), della prima articolazione metatarso-falangea (MTF) e la prima articolazione carpometacarpale (CMC). In secondo luogo, i criteri possono essere applicati solo a quei pazienti nei quali la sinovite osservata non sia meglio spiegata da un'altra diagnosi. \n"),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.2.', metadata={'title': ' Criteri classificativi per Artrite reumatoide', 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content="1.2. Criteri classificativi per Artrite reumatoide\nPer classificare un paziente come affetto o meno da artrite reumatoide conclamata, è necessario ottenere un'anamnesi della durata dei sintomi, una valutazione approfondita delle articolazioni e almeno un test sierologico (fattore reumatoide/RF o anticorpi anti peptide ciclico citrullinato/aCCP) e una indice di fase acuta (velocità di eritrosedimentazione (VES) o proteina C-reattiva (PCR)).\n\nCriteri classificativi dell'artrite reumatoide(algoritmo basato sul punteggio: un punteggio maggiore di 6/10 è necessario per classificare un paziente come affetto da artrite reumatoide definita)\n- Coinvolgimento articolare:\n\t- 1 grande articolazione: 0 punti\n\t- 2-10 grandi articolazioni: 1 punto\n\t- 1-3 piccole articolazione (con o senza il coinvolgimento delle grandi articolazioni): 2 punti\n\t- 4-10 piccole articolazione (con o senza il coinvolgimento delle grandi articolazioni): 3 punti\n\t- più di 10 articolazioni (almeno 1 piccola articolazione): 5 punti\n- Sierologia (almeno il risultato di un test è necessario per la classificazione):\n\t- fattore reumatoide negativo e accp negativo: 0 punti\n\t- fattore reumatoide o accp positivo a basso titolo: 2 punti\n\t- fattore reumatoide o accp positivo ad alto titolo: 3 punti\n- Reattanti della fase acuta (per la classificazione il risultato di almeno 1un test)\n\tPCR normale e VES normale: 0 punti \n\tPCR anormale o VES anormale: 1 punto\n- Durata dei sintomi\n\t<6 settimane: 0 punti\n\t≥6 settimane: 1 punto.\n\nI criteri sono finalizzati alla classificazione dei pazienti che di recente esordio. Inoltre, pazienti con malattia erosiva tipica dell'artrite reumatoide (AR) con un'anamnesi compatibile con il precedente soddisfacimento dei criteri del 2010 dovrebbero essere classificati come affetti da artrite reumatoide.\nPazienti con malattia di lunga durata, compresi quelli la cui malattia è inattiva (con o senza trattamento) che, sulla base di dati disponibili retrospettivamente, hanno precedentemente soddisfatto criteri del 2010 dovrebbero essere classificati come affetti da artrite reumatoide. \n"),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.3.', metadata={'title': ' Altre presentazioni cliniche: erosioni e malattia tardiva', 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content="1.3. Altre presentazioni cliniche: erosioni e malattia tardiva\nOltre a quelli di nuova presentazione, è stato necessario prendere in considerazione altri tre gruppi di pazienti: (1) quelli con erosioni tipiche dell'artrite reumatoide sono stati ritenuti compatibili con artrite reumatoide e possono essere classificati come tali, (2) quelli con malattia di lunga durata, attiva o inattiva, che, sulla base dei dati retrospettivamente disponibili, hanno precedentemente soddisfatto i criteri classificativi, possono analogamente essere classificati come affetti da artrite reumatoide definita e (3) nell'ambito della malattia precoce che viene trattata, possono essere classificati come affetti da artrite reumatoide gli individui che non soddisfano i nuovi criteri al momento della presentazione iniziale, ma possono farlo con l'evolversi della loro condizione nel tempo. \n"),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.4.', metadata={'title': ' Glossario delle definizioni', 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content='1.4. Glossario delle definizioni\n'),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.4.1.', metadata={'title': ' Definizione di articolazione coinvolta', 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content="1.4.1. Definizione di articolazione coinvolta\nIl coinvolgimento articolare si riferisce a qualsiasi articolazione che presenta tumefazione o dolorabilità all'esame che è indicativa di una sinovite attiva. Inoltre, qualsiasi articolazione con una lesione recente nota che potrebbe contribuire a tumefazione e dolorabilità non deve essere presa in considerazione.\nPer confermare il riscontro clinico di sinovite si possono utilizzare ulteriori prove di infiammazione articolare ottenute con altre tecniche di imaging (come la risonanza magnetica o l’ecografia).\n"),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.4.2.', metadata={'title': ' Definizione di piccole articolazioni', 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content='1.4.2. Definizione di piccole articolazioni\nLe piccole articolazioni comprendono le articolazioni MCF, interfalangee prossimali, dalla seconda alla quinta MTF, le articolazioni interfalangee del pollice e i polsi.\n'),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.4.3.', metadata={'title': ' Definizione di grandi articolazioni', 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content='1.4.3. Definizione di grandi articolazioni\nIl termine \\"grandi articolazioni\\" si riferisce a spalle, gomiti, anche, ginocchia e caviglie. \n'),
#  Document(id='Criteri di classificazione dell_artrite reumatoide 2010 .txt--paragraph1.5.', metadata={'title': ' Discussione', 'source': 'Criteri di classificazione dell_artrite reumatoide 2010 '}, page_content="1.5. Discussione\nÈ importante, tuttavia, sottolineare che i criteri sono da applicare solo a pazienti eleggibili, nei quali la presenza di un'evidente sinovite clinica in almeno un'articolazione è centrale. I criteri non dovrebbero essere applicati a pazienti con semplice artralgia o a individui normali.\nLa simmetria non è una caratteristica dei nuovi criteri, in quanto non ha peso indipendente in nessuna fase del processo di sviluppo dei criteri.\nL'uso dei nuovi criteri dovrebbe essere limitato a una popolazione target in cui non esiste una spiegazione alternativa (cioè una diagnosi definita) per la loro sinovite."),
#  Document(id='EULAR artralgia.txt--paragraph1.', metadata={'title': " Definizione EULAR dell'artralgia sospetta per progressione verso l'artrite reumatoide", 'source': 'EULAR artralgia'}, page_content="1. Definizione EULAR dell'artralgia sospetta per progressione verso l'artrite reumatoide\nDurante la transizione verso l'artrite reumatoide (AR) molti pazienti attraversano una fase caratterizzata dalla presenza di sintomi senza presentare sinovite clinicamente evidente. Questi sintomi non sono ben caratterizzati.\nQuesto studio si propone di definire le caratteristiche cliniche dei pazienti con artralgia che sono considerati a rischio di AR.\nUn modello multivariato basato sui dati ha identificato sette parametri rilevanti per caratterizzare pazienti con artralgia a rischio di artrite reumatoide: durata dei sintomi <1 anno, sintomi delle articolazioni metacarpo-falangee (MCF),durata della rigidità mattutina ≥60 min, sintomi più gravi al mattino presto, parente di primo grado con RA, difficoltà a stringere il pugno e squeeze test/test della gronda positivo delle articolazioni MCF.\n"),
#  Document(id='EULAR artralgia.txt--paragraph1.1.', metadata={'title': ' Introduzione', 'source': 'EULAR artralgia'}, page_content="1.1. Introduzione\nLo sviluppo dell'artrite reumatoide (AR) è un processo a più fasi: (1) presenza di fattori di rischio genetici e ambientali per l'AR, (2) autoimmunità sistemica associata alla AR, (3) sintomi senza artrite clinica, (4) artrite indifferenziata e infine (5) AR. I pazienti con artralgia clinicamente sospetta (CSA) presentano sintomi articolari senza segni clinici di artrite e sono considerati a maggior rischio di progressione verso l'AR. \nL'artralgia clinicamente sospetta (CSA) non è di per sé una malattia, ma una combinazione di sintomi e segni. È stato previsto che le caratteristiche cliniche da sole non sono sufficientemente predittive di AR, che una combinazione di fattori clinici e altri fattori (esempio autoanticorpi, risultati di imaging) sono necessari per identificare i pazienti con AR imminente.\n"),
#  Document(id='gotta.txt--paragraph1.', metadata={'title': ' Criteri di classificazione della Gotta 2015', 'source': 'gotta'}, page_content="1. Criteri di classificazione della Gotta 2015\nI fattori chiave iniziali identificati come importanti per la classificazione della gotta sono stati la presenza di cristalli urato monosodico, la distribuzione del coinvolgimento articolare, l'intensità degli episodi sintomatici, il tempo di raggiungimento del dolore massimo e di risoluzione, la natura episodica dei sintomi, la presenza di tofi rilevati clinicamente, il livello di urato/acido urico sierico e le caratteristiche di imaging/agl esami strumentali.\n\n"),
#  Document(id='gotta.txt--paragraph1.1.', metadata={'title': ' Criteri di ingresso, di sufficienza e di esclusione', 'source': 'gotta'}, page_content="1.1. Criteri di ingresso, di sufficienza e di esclusione\nI criteri di classificazione devono essere applicabili solo alle persone con malattia sintomatica, poiché la prognosi della malattia asintomatica non è attualmente ben delineata in letteratura, e per consentire una categorizzazione basata sulle caratteristiche degli episodi sintomatici. Il criterio di ingresso è stato definito come il verificarsi di almeno un episodio di gonfiore, dolore o dolorabilità in un'articolazione periferica o in una borsa sierosa. \n\n"),
#  Document(id='gotta.txt--paragraph1.2.', metadata={'title': ' Domini e categorie', 'source': 'gotta'}, page_content="1.2. Domini e categorie\nGli episodi sintomatici sono stati definiti come quelli in cui erano presenti gonfiore, dolore o dolorabilità in un'articolazione periferica o in una borsa sierosa. Per quanto riguarda la distribuzione del coinvolgimento articolare, si è convenuto che un coinvolgimento della prima articolazione metatarso-falangea, della caviglia o del medio piede/mediotarso come parte di una presentazione poliarticolare, sebbene possibile nella gotta, non era sufficientemente specifico per la gotta.\n\nIl decorso temporale degli episodi sintomatici doveva essere considerato indipendentemente dal trattamento antinfiammatorio. Per quanto riguarda i tofi rilevati clinicamente, è stata sviluppata una definizione precisa in termini di aspetto e localizzazione per aiutare la differenziazione da altri noduli sottocutanei che possono essere confusi con i tofi.\n\nL'urato/acido urico sierico è stato considerato un elemento obbligatorio dei criteri di classificazione.\n\nPer il dominio del liquido sinoviale, il liquido deve essere aspirato da un'articolazione o da una borsa sintomatica (sempre) e valutato da un osservatore esperto. Se l'aspirato di liquido sinoviale era positivo per la presenza di cristalli di urato monosodico, l'individuo sarebbe stato classificato come affetto da gotta.\n\nLe modalità di imaging con sufficienti dati pubblicati e l'esperienza degli sperimentatori a sostegno della loro utilità nell'identificare accuratamente il deposito di urato/acido urico sono state l'ecografia e la dual emission computed tomography/DECT. Per l'evidenza ecografica del deposito di urato/acido urico, il reperto richiesto è il segno del doppio contorno (DCS), definito come un aumento irregolare iperecoico sulla superficie della cartilagine ialina, indipendente dall'angolo di insonazione del fascio di ultrasuoni. Per la DECT, il deposito di urato/acido urico è definito come la presenza di urato colorato in siti articolari o periarticolari. Il punteggio di questo dominio di imaging è applicabile solo a un'articolazione o a una borsa sintomatica (sempre). L'evidenza per immagini di un danno articolare correlato alla gotta deve essere valutata sulla base di una radiografia convenzionale delle mani e/o dei piedi che dimostri almeno un'erosione correlata alla gotta, definita come una interruzione della corticale ossea con margine sclerotico e bordo sporgente.\n\n\n"),
#  Document(id='gotta.txt--paragraph1.3.', metadata={'title': ' Punteggio dei criteri finali', 'source': 'gotta'}, page_content="1.3. Punteggio dei criteri finali\nI criteri possono essere sintetizzati nella seguente lista: almeno un episodio acuto di dolore o tumefazione in un’articolazione o una borsa sierosa, presenza di cristalli di urato monosodico nel liquido sinoviale o in un tofo,coinvolgimento della caviglia o del mediotarso,coinvolgimento della prima articolazione metatarsofalangea,eritema/arrossamento sovrastante l’articolazione,difficoltà alla deambulazione,ipersensibilità con dolore al tocco e alla pressione dell’articolazione coinvolta,evidenza clinica di tofi,incremento dei livelli sierici di acido urico,evidenza all’ecografia o alla DECT di immagini compatibili con depositi di acido urico (tofi, doppio contorno).\n\nIl massimo punteggio possibile nei criteri finali è 23. Un punteggio soglia maggiore o uguale di 8 classifica un individuo come affetto da gotta. Se il liquido sinoviale e' negativo per cristalli di urato monosodico, vengono sottratti 2 punti dal punteggio totale. Allo stesso modo, se il livello di urato/acido urico sierico è minore di 4 mg/dL (minore di 0,24 mmol/L), vengono sottratti 4 punti dal punteggio totale. Questo approccio è stato adottato per sottolineare che questi risultati riducono la probabilità di gotta. Se non viene eseguita la diagnostica per immagini, a queste categorie viene attribuito un punteggio pari a 0.\n"),
#  Document(id='IBP.txt--paragraph1.', metadata={'title': ' Lombalgia infiammatoria', 'source': 'IBP'}, page_content="1. Lombalgia infiammatoria\nLa lombalgia infiammatoria  è un importante sintomo  nei pazienti affetti da spondiloartrite assiale (SpA) e rilevante per la classificazione e la diagnosi.\nCinque parametri spiegano meglio la lombalgia infiammatoria secondo esperti e sono: il miglioramento con l'esercizio fisico, il dolore notturno, l’insorgenza insidiosa, l’età d'insorgenza inferiore ai 40 anni e nessun miglioramento con il riposo.\nTre parametri non contribuiscono in modo indipendente alla lombalgia infiammatoria: durata della lombalgiamaggiore di 3 mesi, dolore alternato ai glutei e rigidità mattutina.\nI nuovi criteri rappresentano una sorta di sintesi dei criteri esistenti. I criteri 'esordio della malattia a un'età inferiore ai 40 anni', 'esordio insidioso' e 'miglioramento con l'esercizio fisico' rappresentano anche tre dei cinque criteri di Calin. È interessante notare che la 'rigidità mattutina' è stata sostituita da 'dolore notturno', che descrive un dominio in qualche modo simile.\nIl valore della rigidità mattutina come parametro della lombalgia infiammatoria sembra essere migliore quando c'è una differenziazione tra minore di 30 minuti e maggiore di 30 minuti.\nIn generale, tuttavia, la durata dei sintomi maggiore di 3 mesi rimane un importante parametro da valutare per pazienti con lombalgia non specifica,  quale criterio richiedente ulteriori accertamenti anche prima di considerare la spondiloartrite assiale (SpA ) come una possibile diagnosi e definire se la lombalgia abbia le caratteristiche della lombalgia infiammatoria.\n"),
#  Document(id='referral_2009.txt--paragraph1.', metadata={'title': ' Raccomandazione di invio precoce allo specialista per le nuove diagnosi di artrite reumatoide: sviluppo di una guida clinica basata sulle evidenze', 'source': 'referral_2009'}, page_content="1. Raccomandazione di invio precoce allo specialista per le nuove diagnosi di artrite reumatoide: sviluppo di una guida clinica basata sulle evidenze\nLe evidenze cliniche supportano fortemente le osservazioni che il danno strutturale si verifica precocemente nell' artrite reumatoide attiva e che il trattamento precoce con DMARD migliora l'esito a lungo termine della malattia. Le osservazioni indicano che è consigliabile rivolgersi rapidamente a un reumatologo quando si sospetta la presenza di AR. Questo può essere supportato dalla presenza di uno dei seguenti elementi: più di 3 articolazioni tumefatte, coinvolgimento delle metatarso-falangee/metacarpo-falangee e rigidità mattutina >30 minuti.\n\nI primi sintomi dell'artrite reumatoide sono talvolta aspecifici e inconcludenti.\nEsiste una finestra di opportunità relativamente breve per iniziare il trattamento con DMARD, che può migliorare in modo sostanziale l’outcome a lungo termine della malattia e della qualità di vita complessiva dei pazienti con artrite reumatoide attiva.\n"),
#  Document(id='referral_2009.txt--paragraph1.1.', metadata={'title': " Progressione clinica dell'artrite reumatoide: il danno articolare si verifica precocemente", 'source': 'referral_2009'}, page_content="1.1. Progressione clinica dell'artrite reumatoide: il danno articolare si verifica precocemente\nCirca il 75% dei pazienti con AR precoce presenta erosioni articolari e sviluppa le erosioni iniziali entro i primi due anni dall'insorgenza dei sintomi.\nQueste prime indagini prospettiche presentano una forte evidenza che il danno articolare si verifica precocemente nel decorso dell'artrite reumatoide.\nI risultati dello studio indicano che la scintigrafia, l’ecografia muscoloscheletrica e la risonanza magnetica sono significativamente più sensibili della radiografia convenzionale nel rilevare le prime infiammazioni dei tessuti molli e dei processi distruttivi dell'articolazione prima che il danno radiografico diventi evidente.\n"),
#  Document(id='referral_2009.txt--paragraph1.2.', metadata={'title': " Il trattamento DMARD precoce migliora l'esito dell'artrite reumatoide", 'source': 'referral_2009'}, page_content="1.2. Il trattamento DMARD precoce migliora l'esito dell'artrite reumatoide\nIn ogni studio il gruppo trattato precocemente con DMARD ha mostrato un miglioramento significativamente maggiore nei parametri di efficacia rispetto ai gruppi il cui trattamento è stato ritardato. L'intervento precoce ha migliorato la funzionalità del paziente e ha ridotto o rallentato la progressione radiografica della malattia. Pazienti con una malattia di più lunga durata non hanno avuto una risposta altrettanto buona rispetto ai pazienti trattati in stadi più precoci della malattia.\n"),
#  Document(id='referral_2009.txt--paragraph1.3.', metadata={'title': " Il trattamento DMARD precoce migliora l'esito a lungo termine e la qualità della vita del paziente", 'source': 'referral_2009'}, page_content="1.3. Il trattamento DMARD precoce migliora l'esito a lungo termine e la qualità della vita del paziente\nI pazienti con AR che si sono presentati e sono stati trattati precocemente hanno ottenuto risultati migliori rispetto a quelli che si sono presentati tardivamente. Lo studio ha concluso che il trattamento precoce migliora la prognosi e che, di conseguenza, i pazienti possono avere una malattia più lieve.\nL'evidenza clinica ha indicato che l'uso a lungo termine di DMARD non previene necessariamente la progressione radiografica del danno articolare, ma rallenta significativamente il tasso di progressione rispetto al trattamento con farmaci antinfiammatori non steroidei (FANS) da soli.\n"),
#  Document(id='referral_2009.txt--paragraph1.4.', metadata={'title': ' Esperienza clinica', 'source': 'referral_2009'}, page_content="1.4. Esperienza clinica\nIl problema intrinseco al trattamento dell'artrite reumatoide precoce è il lungo lasso di tempo tra l'insorgenza della malattia e l'invio a un reumatologo per un trattamento accurato e specifico. L'analisi specifica del tempo che intercorre tra l'insorgenza dei sintomi e la diagnosi del trattamento, indica due fattori che ritardano la diagnosi: in primo luogo, il tempo che intercorre tra la comparsa dei sintomi e la successiva visita del paziente al medico di base e, in secondo luogo, il tempo necessario per formulare la diagnosi.\nI criteri di riferimento per il gruppo AR precoce sono stati definiti semplicemente come pazienti che presentavano almeno due delle seguenti caratteristiche: dolore articolare, tumefazione articolare o riduzione della mobilità articolare con una durata inferiore a due anni.\n"),
#  Document(id='referral_2009.txt--paragraph1.5.', metadata={'title': ' Algoritmo di invio precoce allo specialista per le nuove diagnosi di artrite reumatoide', 'source': 'referral_2009'}, page_content="1.5. Algoritmo di invio precoce allo specialista per le nuove diagnosi di artrite reumatoide\nE' consigliabile un rapido invio a un reumatologo in caso di sospetto clinico di artrite reumatoide, che può essere supportato dalla presenza di uno dei seguenti elementi (evidenza di grado C):\n- più di 3 articolazioni tumefatte\n- coinvolgimento metatarsofalangee/metacarpofalangee (squeeze test/segno della gronda positivo)\n-rigidità mattutina maggiore di 30 minuti\n\nÈ stato dimostrato che i pazienti affetti da artrite reumatoide hanno un esito migliore a lungo termine, se trattati da un reumatologo (evidenza di grado C).\nÈ dimostrato che un ritardo >12 settimane nel trattamento si traduce in una mancata opportunità di migliorare l'esito a lungo termine (evidenza di grado C).\nLa positività al fattore reumatoide, aumento degli indici di fase acuta, ed erosioni alla radiografia sono associati a un esito sfavorevole. La loro assenza alla presentazione non dovrebbe precludere la diagnosi o l’invio (grado C evidenza).\nI FANS possono mascherare i segni e i sintomi alla presentazione (evidenza di grado D).\nI corticosteroidi non dovrebbero essere prescritti senza una diagnosi accurata (evidenza di grado D).\n"),
#  Document(id='referral_2009.txt--paragraph1.6.', metadata={'title': " Raccomandazione di invio precoce per l'artrite reumatoide", 'source': 'referral_2009'}, page_content="1.6. Raccomandazione di invio precoce per l'artrite reumatoide\nI danni strutturali permanenti si verificano nelle fasi iniziali dell'artrite reumatoide attiva e l'intervento precoce con DMARD rallentano la progressione del danno strutturale dell'articolazione e migliorano l'esito a lungo termine e la qualità di vita complessiva del paziente.\nL'invio è raccomandato quando c'è il sospetto clinico di artrite reumatoide ponendo l'accento sul sospetto, in quanto il ritardo indotto dal desiderio di una diagnosi confermata spesso si traduce in una progressione della malattia prima dell'inizio di un trattamento efficace.\nCiò è supportato dall'osservazione che i marcatori sierologici di artrite reumatoide sono spesso negativi nelle fasi iniziali della malattia.\nIl test di compressione segno della gronda è una tecnica utile per la valutazione clinica di un gruppo di piccole articolazioni adiacenti, come le articolazioni metacarpo-falangee e metatarso-falangee, e l'uso di questo test diagnostico nella valutazione dell'artrite reumatoide precoce è stato recentemente validato.\nLa dolorabilità in una singola articolazione all'interno del gruppo può essere isolata mediante palpazione delicata delle singole articolazioni. La somma del numero di articolazioni dolorabili consente in questo modo al medico di determinare il numero di articolazioni colpite.\n"),
#  Document(id='spondiloartrite_assiale.txt--paragraph1.', metadata={'title': ' Sviluppo di criteri classificativi per la spondiloartrite assiale (parte II): validazione e selezione finale (ASAS)', 'source': 'spondiloartrite_assiale'}, page_content="1. Sviluppo di criteri classificativi per la spondiloartrite assiale (parte II): validazione e selezione finale (ASAS)\nI nuovi criteri classificativi della spondiloartriti assiali selezionati dalla Società Internazionale per la Valutazione della Spondiloartrite (ASAS) sono due: la presenza di sacroileite (definita sia tramite radiografia sia attraverso l'infiammazione attiva delle articolazioni sacroiliache tramite imaging a risonanza magnetica) più almeno una caratteristica clinica tipica della spondiloartrite oppure la presenza dell’antigene HLA-B27 più almeno altre due caratteristiche cliniche tipiche della spondiloartrite.\n"),
#  Document(id='spondiloartrite_assiale.txt--paragraph1.1.', metadata={'title': ' Risultati', 'source': 'spondiloartrite_assiale'}, page_content="1.1. Risultati\nPazienti eleggibili devono avere necessariamente una lombalgia cronica(da più di tre mesi) di origine sconosciuta (senza diagnosi definitiva) esordita prima dei 45 anni di età, con o senza sintomi articolari periferici.\n\nI criteri classificativi finali per la spondiloartrite assiale (SpA) selezionati dalla Società internazionale di valutazione della spondiloartrite (ASAS) comprendono sia pazienti con che senza sacroileite radiografica definita. Secondo i criteri, un paziente con mal di schiena cronico (>3 mesi) e con un'età di insorgenza inferiore a 45 anni può essere classificato in presenza di sacroileite (definita sia tramite radiografia sia attraverso l'infiammazione attiva delle articolazioni sacroiliache tramite imaging a risonanza magnetica) più almeno una caratteristica clinica tipica della spondiloartrite oppure in presenza dell’antigene HLA-B27 più almeno altre due caratteristiche cliniche tipiche della spondiloartrite. Sensibilità 82.9%, specificità 84.4%; n = 649 pazienti con dolore cronico alla schiena ed età di insorgenza inferiore a 45 anni. Il braccio di imaging (sacroileite) da solo ha una sensibilità del 66,2% e una specificità del 97,3%.\n\nLe caratteristiche della spondiloartrite sono la lombalgia infiammatoria, l'artrie,l'entesite,l'uveite,la dattilica, la psoriasi, il morbo di Crohn/colite ulcerosa, una buona risposta agli anti infiammatori non steroide (FANS), un'anamnesi familiare di spondiloartrite, HLA-B27 e un alto livello di PCR (proteina C-reattiva).\n\nPer quanto riguarda la lombalgia infiammatoria, le seguenti caratteristiche sono state registrate (si vs no): un esordio insidioso, rigidità mattutina, miglioramenti con esercizio fisico, miglioramenti con il riposo, dolore alla natica a lateralità alternante, dolore notturno che migliorava alzandosi dal letto.\nUna buona risposta del mal di schiena ad una dose piena di medicinali anti-infiammatori non steroidei (FANS) è stata definita come marcato miglioramento o piena risoluzione della lombalgia. \nÉ stata inoltre documentata la presenza di manifestazioni extraspinali (presenti o passate), cioè, entesite, artrite periferica, uveite, dattilite, psoriasi, Malattie Infiammatorie Croniche Intestinali (IBD o MICI) e una storia familiare positiva di spondiloartrite (spondilite anchilosante, artrite reattiva, psoriasi, IBD o MICI, uveite).\nSono state fatte radiografie del bacino a tutti i pazienti e la sacroileite è stata classificata per ogni articolazione sacroiliaca separatamente (classi da 0 a 4) secondo i criteri di New York modificati.\nI risultati della risonanza magnetica sono stati documentati come presenza o assenza di segni\ntipici di infiammazione attiva.\nDa un punto di vista clinico è stato deciso che coloro che rispondono scarsamente al FANS non dovrebbero essere esclusi dall'essere classificati come affetti da spondiloartrite tramite il braccio clinico dei criteri.\n"),
#  Document(id='spondiloartrite_assiale.txt--paragraph1.2.', metadata={'title': ' Discussione', 'source': 'spondiloartrite_assiale'}, page_content="1.2. Discussione\nQuesti criteri comprendono pazienti con sacroileite radiografica accertata (che sarà classificata come spondiloartrite assiale)e anche pazienti che non hanno (ancora) sviluppato una sacroileite radiografica e, pertanto, sono definiti come spondiloartrite assiale non radiografica.\nSebbene la performance dei criteri in questo studio non è stata compromesso dall'esclusione di parametri quali PCR, dattilite o IBD/MICI, il gruppo ASAS ha ritenuto che questi parametri dovessero essere mantenuti nell'elenco perché rappresentano domini riconoscibili nell’ambito delle caratteristiche cliniche della spondiloartrite. Da notare: le misure di mobilità della colonna vertebrale non sono state incluse nei nuovi criteri perché non differenziavano tra spondiloartrite assiale e assenza di spondiloartrite in pazienti con malattia relativamente precoce.\nNei nuovi criteri, la sacroileite attiva alla risonanza magnetica come uno dei parametri di imaging richiede la presenza evidente di lesioni infiammatorie attive, rappresentate da edema osseo e sinovite, che sono tipicamente visibili nella sacroileite associata alla spondiloartrite."),
#  Document(id='spondiloartrite_periferica_generale.txt--paragraph1.', metadata={'title': ' Criteri di classificazione della Società Internazionale per la Valutazione della SpondiloArtrite internazionale per la spondiloartrite periferica e la spondiloartrite in generale ', 'source': 'spondiloartrite_periferica_generale'}, page_content='1. Criteri di classificazione della Società Internazionale per la Valutazione della SpondiloArtrite internazionale per la spondiloartrite periferica e la spondiloartrite in generale \nIn questo studio della Società Internazionale per la Valutazione della SpondiloArtrite internazionale (ASAS), due serie di criteri prespecificati sono stati confrontati con i criteri del Gruppo di Studio Europeo sulle Spondiloartropatie (ESSG) e i criteri Amor in pazienti consecutivi di nuova diagnosi con artrite periferica non diagnosticata e/o entesite e/o dattilite che di solito è insorta prima dei 45 anni. Il set finale di criteri identificato è stato rappresentato da: artrite e/o entesite e/o dattilite più (A) uno o più dei seguenti parametri: psoriasi, malattia infiammatoria intestinale, infezione precedente, HLA B27, uveite, sacroileite alla diagnostica per immagini, oppure(B) due o più altri parametri: artrite, entesite, dattilite, lombalgia infiammatoria in passato, storia familiare di spondiloartrite.\nI nuovi criteri di classificazione ASAS per la spondiloartrite periferica hanno dato buoni risultati nei pazienti che presentavano artrite periferica, entesite e/o dattilite. \n'),
#  Document(id='spondiloartrite_periferica_generale.txt--paragraph1.1.', metadata={'title': ' Disegno dello studio e dati clinici e demografici', 'source': 'spondiloartrite_periferica_generale'}, page_content="1.1. Disegno dello studio e dati clinici e demografici\nPazienti con manifestazioni periferiche, tra cui artrite periferica e/o entesite e/o dattilite, esordita prima dei 45 anni di età e assenza di lombalgia sono stati inclusi.\nL'artrite periferica, l'entesite e la dattilite sono state valutate clinicamente.\nI pazienti con diagnosi di spondiloartrite rispetto a quelli senza spondiloartrite  erano più giovani e più spesso di sesso maschile. La manifestazione periferica più frequente è stata l'artrite periferica (46,6%),seguita da entesite (9,8%) e dattilite (1,9%). In totale il 41% dei pazienti presentava una combinazione di manifestazioni periferiche alla prima presentazione, più comunemente artrite più entesite (28,9% di tutti i pazienti). La durata media dell'artrite periferica era di 10.3 (18.6) mesi, mentre quella dell'entesite era di 9.0 (16) mesi. Il tipico pattern di artrite da spondiloartrite (asimmetrica e/o prevalentemente agli arti inferiori) è stato riscontrato nell'86,6% dei 231 pazienti con artrite.\nL'analisi di regressione logistica multivariata ha rivelato che l'età (p=0,034),HLA-B27 (p<0,001), un'anamnesi familiare positiva per spondiloartrite (p=0,018),entesite (p<0,001), psoriasi (p=0,004) e una sacroileite radiografica (p=0,004) sono associati in modo indipendente alla spondiloartrite.\nI pazienti inclusi in questo studio avevano un'artrite periferica, entesite e/o dattilite di durata inferiore a 1 anno. Tutti i pazienti erano di nuova diagnosi, con malattia non diagnosticata e con il solo sospetto di spondiloartrite.\n")]
